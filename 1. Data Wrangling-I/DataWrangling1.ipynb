# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("Iris.csv")
dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dataset.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
dataset.shape
# Out:
# (150, 6)

# %%
dataset.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
dataset.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
dataset.columns.values
# Out:
# array(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm',
#        'PetalWidthCm', 'Species'], dtype=object)

# %%
dataset.columns.values.tolist()
# Out:
# ['Id',
#  'SepalLengthCm',
#  'SepalWidthCm',
#  'PetalLengthCm',
#  'PetalWidthCm',
#  'Species']

# %%
dataset['Id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 145    146
# 146    147
# 147    148
# 148    149
# 149    150
# Name: Id, Length: 150, dtype: int64

# %%
dataset['SepalLengthCm']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
dataset['SepalWidthCm']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SepalWidthCm, Length: 150, dtype: float64

# %%
dataset.to_numpy()
# Out:
# array([[1, 5.1, 3.5, 1.4, 0.2, 'Iris-setosa'],
#        [2, 4.9, 3.0, 1.4, 0.2, 'Iris-setosa'],
#        [3, 4.7, 3.2, 1.3, 0.2, 'Iris-setosa'],
#        [4, 4.6, 3.1, 1.5, 0.2, 'Iris-setosa'],
#        [5, 5.0, 3.6, 1.4, 0.2, 'Iris-setosa'],
#        [6, 5.4, 3.9, 1.7, 0.4, 'Iris-setosa'],
#        [7, 4.6, 3.4, 1.4, 0.3, 'Iris-setosa'],
#        [8, 5.0, 3.4, 1.5, 0.2, 'Iris-setosa'],
#        [9, 4.4, 2.9, 1.4, 0.2, 'Iris-setosa'],
#        [10, 4.9, 3.1, 1.5, 0.1, 'Iris-setosa'],
#        [11, 5.4, 3.7, 1.5, 0.2, 'Iris-setosa'],
#        [12, 4.8, 3.4, 1.6, 0.2, 'Iris-setosa'],
#        [13, 4.8, 3.0, 1.4, 0.1, 'Iris-setosa'],
#        [14, 4.3, 3.0, 1.1, 0.1, 'Iris-setosa'],
#        [15, 5.8, 4.0, 1.2, 0.2, 'Iris-setosa'],
#        [16, 5.7, 4.4, 1.5, 0.4, 'Iris-setosa'],
#        [17, 5.4, 3.9, 1.3, 0.4, 'Iris-setosa'],
#        [18, 5.1, 3.5, 1.4, 0.3, 'Iris-setosa'],
#        [19, 5.7, 3.8, 1.7, 0.3, 'Iris-setosa'],
#        [20, 5.1, 3.8, 1.5, 0.3, 'Iris-setosa'],
# ...

# %%
dataset.T
# Out:
#                        0            1            2            3    \
# Id                       1            2            3            4
# SepalLengthCm          5.1          4.9          4.7          4.6
# SepalWidthCm           3.5          3.0          3.2          3.1
# PetalLengthCm          1.4          1.4          1.3          1.5
# PetalWidthCm           0.2          0.2          0.2          0.2
# Species        Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                        4            5            6            7    \
# Id                       5            6            7            8
# SepalLengthCm          5.0          5.4          4.6          5.0
# SepalWidthCm           3.6          3.9          3.4          3.4
# PetalLengthCm          1.4          1.7          1.4          1.5
# PetalWidthCm           0.2          0.4          0.3          0.2
# Species        Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
# ...

# %%
dataset.sort_index(axis=1,ascending=False)
# Out:
#             Species  SepalWidthCm  SepalLengthCm  PetalWidthCm  PetalLengthCm  \
# 0       Iris-setosa           3.5            5.1           0.2            1.4
# 1       Iris-setosa           3.0            4.9           0.2            1.4
# 2       Iris-setosa           3.2            4.7           0.2            1.3
# 3       Iris-setosa           3.1            4.6           0.2            1.5
# 4       Iris-setosa           3.6            5.0           0.2            1.4
# ..              ...           ...            ...           ...            ...
# 145  Iris-virginica           3.0            6.7           2.3            5.2
# 146  Iris-virginica           2.5            6.3           1.9            5.0
# 147  Iris-virginica           3.0            6.5           2.0            5.2
# 148  Iris-virginica           3.4            6.2           2.3            5.4
# 149  Iris-virginica           3.0            5.9           1.8            5.1
#
#       Id
# 0      1
# 1      2
# ...

# %%
dataset.notnull().sum()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
dataset[dataset.columns[2:4]].iloc[5:10]
# Out:
#    SepalWidthCm  PetalLengthCm
# 5           3.9            1.7
# 6           3.4            1.4
# 7           3.4            1.5
# 8           2.9            1.4
# 9           3.1            1.5

# %%
dataset.sort_values(by="SepalLengthCm")
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 8      9            4.4           2.9            1.4           0.2
# 42    43            4.4           3.2            1.3           0.2
# 38    39            4.4           3.0            1.3           0.2
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 122  123            7.7           2.8            6.7           2.0
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 135  136            7.7           3.0            6.1           2.3
# 131  132            7.9           3.8            6.4           2.0
#
#             Species
# 13      Iris-setosa
# 8       Iris-setosa
# 42      Iris-setosa
# 38      Iris-setosa
# 41      Iris-setosa
# ..              ...
# ...

# %%
dataset.isnull().values.any()
# Out:
# np.False_

# %%
dataset.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
dataset.notnull().sum()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
dataset.iloc[5]
# Out:
# Id                         6
# SepalLengthCm            5.4
# SepalWidthCm             3.9
# PetalLengthCm            1.7
# PetalWidthCm             0.4
# Species          Iris-setosa
# Name: 5, dtype: object

# %%
dataset[0:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
dataset.loc[:,["SepalLengthCm","SepalWidthCm"]]
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
dataset.iloc[:100,:]
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0     1            5.1           3.5            1.4           0.2
# 1     2            4.9           3.0            1.4           0.2
# 2     3            4.7           3.2            1.3           0.2
# 3     4            4.6           3.1            1.5           0.2
# 4     5            5.0           3.6            1.4           0.2
# ..  ...            ...           ...            ...           ...
# 95   96            5.7           3.0            4.2           1.2
# 96   97            5.7           2.9            4.2           1.3
# 97   98            6.2           2.9            4.3           1.3
# 98   99            5.1           2.5            3.0           1.1
# 99  100            5.7           2.8            4.1           1.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 95  Iris-versicolor
# ...

# %%
dataset.iloc[3]
# Out:
# Id                         4
# SepalLengthCm            4.6
# SepalWidthCm             3.1
# PetalLengthCm            1.5
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 3, dtype: object

# %%
dataset.iloc[:,:3]
# Out:
#       Id  SepalLengthCm  SepalWidthCm
# 0      1            5.1           3.5
# 1      2            4.9           3.0
# 2      3            4.7           3.2
# 3      4            4.6           3.1
# 4      5            5.0           3.6
# ..   ...            ...           ...
# 145  146            6.7           3.0
# 146  147            6.3           2.5
# 147  148            6.5           3.0
# 148  149            6.2           3.4
# 149  150            5.9           3.0
#
# [150 rows x 3 columns]

# %%
dataset.iloc[:100,:15]
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0     1            5.1           3.5            1.4           0.2
# 1     2            4.9           3.0            1.4           0.2
# 2     3            4.7           3.2            1.3           0.2
# 3     4            4.6           3.1            1.5           0.2
# 4     5            5.0           3.6            1.4           0.2
# ..  ...            ...           ...            ...           ...
# 95   96            5.7           3.0            4.2           1.2
# 96   97            5.7           2.9            4.2           1.3
# 97   98            6.2           2.9            4.3           1.3
# 98   99            5.1           2.5            3.0           1.1
# 99  100            5.7           2.8            4.1           1.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 95  Iris-versicolor
# ...

# %%
dataset.iloc[3:5,0:2]
# Out:
#    Id  SepalLengthCm
# 3   4            4.6
# 4   5            5.0

# %%
dataset.iloc[[1,2,4],[0,2]]
# Out:
#    Id  SepalWidthCm
# 1   2           3.0
# 2   3           3.2
# 4   5           3.6

# %%
dataset.mode(axis=0)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.0           3.0            1.5           0.2
# 1      2            NaN           NaN            NaN           NaN
# 2      3            NaN           NaN            NaN           NaN
# 3      4            NaN           NaN            NaN           NaN
# 4      5            NaN           NaN            NaN           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            NaN           NaN            NaN           NaN
# 146  147            NaN           NaN            NaN           NaN
# 147  148            NaN           NaN            NaN           NaN
# 148  149            NaN           NaN            NaN           NaN
# 149  150            NaN           NaN            NaN           NaN
#
#              Species
# 0        Iris-setosa
# 1    Iris-versicolor
# 2     Iris-virginica
# 3                NaN
# 4                NaN
# ..               ...
# ...

# %%
dataset["SepalLengthCm"]=5/dataset["SepalLengthCm"]

# %%
dataset.iloc[:,0:5]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1       0.980392           3.5            1.4           0.2
# 1      2       1.020408           3.0            1.4           0.2
# 2      3       1.063830           3.2            1.3           0.2
# 3      4       1.086957           3.1            1.5           0.2
# 4      5       1.000000           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146       0.746269           3.0            5.2           2.3
# 146  147       0.793651           2.5            5.0           1.9
# 147  148       0.769231           3.0            5.2           2.0
# 148  149       0.806452           3.4            5.4           2.3
# 149  150       0.847458           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
dataset.rename(columns={"SepalLengthCm":"NewSepalLengthCm"},inplace=True)

# %%
dataset
# Out:
#       Id  NewSepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1          0.980392           3.5            1.4           0.2
# 1      2          1.020408           3.0            1.4           0.2
# 2      3          1.063830           3.2            1.3           0.2
# 3      4          1.086957           3.1            1.5           0.2
# 4      5          1.000000           3.6            1.4           0.2
# ..   ...               ...           ...            ...           ...
# 145  146          0.746269           3.0            5.2           2.3
# 146  147          0.793651           2.5            5.0           1.9
# 147  148          0.769231           3.0            5.2           2.0
# 148  149          0.806452           3.4            5.4           2.3
# 149  150          0.847458           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
dataset["SepalWidthCm"]=dataset["SepalWidthCm"].astype("int")

# %%
dataset
# Out:
#       Id  NewSepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1          0.980392             3            1.4           0.2
# 1      2          1.020408             3            1.4           0.2
# 2      3          1.063830             3            1.3           0.2
# 3      4          1.086957             3            1.5           0.2
# 4      5          1.000000             3            1.4           0.2
# ..   ...               ...           ...            ...           ...
# 145  146          0.746269             3            5.2           2.3
# 146  147          0.793651             2            5.0           1.9
# 147  148          0.769231             3            5.2           2.0
# 148  149          0.806452             3            5.4           2.3
# 149  150          0.847458             3            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# ...

# %%
dataset.drop(columns='Id',inplace=True)

# %%
dataset
# Out:
#      NewSepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0            0.980392             3            1.4           0.2
# 1            1.020408             3            1.4           0.2
# 2            1.063830             3            1.3           0.2
# 3            1.086957             3            1.5           0.2
# 4            1.000000             3            1.4           0.2
# ..                ...           ...            ...           ...
# 145          0.746269             3            5.2           2.3
# 146          0.793651             2            5.0           1.9
# 147          0.769231             3            5.2           2.0
# 148          0.806452             3            5.4           2.3
# 149          0.847458             3            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# ...

# %%
dataset.head()
# Out:
#    NewSepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0          0.980392             3            1.4           0.2  Iris-setosa
# 1          1.020408             3            1.4           0.2  Iris-setosa
# 2          1.063830             3            1.3           0.2  Iris-setosa
# 3          1.086957             3            1.5           0.2  Iris-setosa
# 4          1.000000             3            1.4           0.2  Iris-setosa

# %%
df=pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
dummies = pd.get_dummies(df.Species)

# %%
dummies.tail()
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 145        False            False            True
# 146        False            False            True
# 147        False            False            True
# 148        False            False            True
# 149        False            False            True

# %%
merged_data = pd.concat([df,dummies],axis=1)

# %%
merged_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  Iris-setosa  Iris-versicolor  Iris-virginica
# 0       Iris-setosa         True            False           False
# ...
